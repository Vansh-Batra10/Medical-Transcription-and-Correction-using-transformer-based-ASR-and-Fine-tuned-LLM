# %% [markdown]
# ### Installation

# %%
# !pip install --q --upgrade pip
# !pip install --q --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]
# !pip install --q flash-attn --no-build-isolation

# %%
# !pip install pytube

# %% [markdown]
# ### Import required packages

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# %%
device

# %%
torch_dtype

# %%
model_id = "openai/whisper-large-v3"

# %%
model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=15,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

# %%
pipe

# %%
audio = ""

# %%
result = pipe(audio) # v2 gives better results if you don't provide a language.

# %%
from pytube import Playlist

# URL of the YouTube playlist
playlist_url = 'https://www.youtube.com/playlist?list=PLEXdUb0osUjZnNmluAaWzeynXa4k22j_2'

# Create a Playlist object
playlist = Playlist(playlist_url)

# Fetch the video URLs in the playlist
video_links = playlist.video_urls

# Print the video URLs
for i, link in enumerate(video_links, start=1):
    print(f"Video {i}: {link}")

video_links=video_links[3:68]

# %%
# video_links=["https://www.youtube.com/watch?v=B4CH89nB2F0&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=21","https://www.youtube.com/watch?v=i3m0mZ-1qcI&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=22","https://www.youtube.com/watch?v=6o86YDwIoc0&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=23","https://www.youtube.com/watch?v=54EF6g6YSRY&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=24","https://www.youtube.com/watch?v=oESPgbmFWt0&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=25","https://www.youtube.com/watch?v=oM28T216eiM&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=26","https://www.youtube.com/watch?v=ZLgMe46Va54&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=27","https://www.youtube.com/watch?v=-UgI-06Qq70&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=28","https://www.youtube.com/watch?v=NfADerzI1xM&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=34","https://www.youtube.com/watch?v=ECkr2K76LOc&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=35","https://www.youtube.com/watch?v=LOjuPoRE058&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=36","https://www.youtube.com/watch?v=KxfLa68dSsM&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=37","https://www.youtube.com/watch?v=cM2KPLJY0VA&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=38","https://www.youtube.com/watch?v=EIIG-ojXo4c&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=39","https://www.youtube.com/watch?v=GBQu7IOuLXk&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=41","https://www.youtube.com/watch?v=8azjcjNAXJg&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=42","https://www.youtube.com/watch?v=t7xpagnBuyI&list=PLEXdUb0osUjafUEEFkOA5WPkua4dyaGp5&index=53","https://www.youtube.com/watch?v=l7qnlrvtQr4&list=PLEXdUb0osUjZCe7tBNWhHcU_bmBICHyrw&index=101","https://www.youtube.com/watch?v=-VH_DQA2LfE&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=29","https://www.youtube.com/watch?v=s90Izfjy-ms&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=36","https://www.youtube.com/watch?v=gA3_PvdtBJk&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=37","https://www.youtube.com/watch?v=M5x5K_Hoq5w&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=38","https://www.youtube.com/watch?v=usAXk0iXIbI&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=39","https://www.youtube.com/watch?v=5dISN_2o9cU&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=40","https://www.youtube.com/watch?v=Ows3LM8QQAk&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=41","https://www.youtube.com/watch?v=ZdsCGBViSLI&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=42","https://www.youtube.com/watch?v=Y7m3-siWARs&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=43","https://www.youtube.com/watch?v=nnb9pGWO0o8&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index=44","https://www.youtube.com/watch?v=SXQ0Geq8oSA&list=PLEXdUb0osUjYSjn1D9PGFNtmTOS-Rq0H6&index
        stream = yt.streams.filter(only_audio=True).first()
        video_file_path ='video_audio.mp4'
        stream.download(output_path="./video", filename='video_audio')
        return video_file_path
    except Exception as e:
        print(f"Error downloading video: {str(e)}")
        return None

def convert_audio_to_wav(video_file_path, download_dir):
    audio_file_path = './video/video_audio'

    audio = AudioSegment.from_file(audio_file_path, format="mp4")
    audio.export(audio_file_path, format="mp3")

    return audio_file_path

def transcribe_audio(audio_file_path):
    # Use your speech-to-text model or API here
    audio="./video/video_audio"
    result = pipe(audio)
    return result.get('text', '')

def transcribe_video_audio(video_url, download_dir):
    video_file_path = download_youtube_video(video_url, download_dir)

    if video_file_path is not None:
        audio_file_path = convert_audio_to_wav(video_file_path, download_dir)
        transcribed_text = transcribe_audio(audio_file_path)
        return transcribed_text

transcribed_texts = []


# Assuming video_links is a list of YouTube video URLs
for video_url in video_links:
    transcribed_text = transcribe_video_audio(video_url, download_directory)
    if transcribed_text:
        transcribed_texts.append(transcribed_text)

# Print the transcribed text for each video
for i, text in enumerate(transcribed_texts, start=1):
    print(f"Transcribed Text for Video {i}:")
    print(text)

# %%
transcribed_texts

# %%
result['text']

# %%
result['chunks']

# %%
# %%timeit
result = pipe(audio, generate_kwargs={"language": "english"})

# %%
import csv
csv_file_path = "data.csv"

# Open the CSV file in write mode and create a CSV writer
with open(csv_file_path, mode='a', newline='',encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)

    # Write the header row
    csv_writer.writerow(["Original Paragraph"])  # Header for your column

    # Write data to the column
    for string in transcribed_texts:
        csv_writer.writerow([string])

print("Data has been written to the CSV file.")

# %%
# translation

# result = pipe(audio,
#               return_timestamps=True,
#               generate_kwargs={"language": "french", "task": "translate"})


# print(result["chunks"])

# %%
result = pipe(audio, return_timestamps=True)
print(result["chunks"])

# %%
# result = pipe(audio, return_timestamps="word")
# print(result["chunks"])

# %% [markdown]
# ### Use Flash Attention

# %%
# model = AutoModelForSpeechSeq2Seq.from_pretrained(
#     model_id,
#     torch_dtype=torch_dtype,
#     low_cpu_mem_usage=True,
#     use_safetensors=True,
#     use_flash_attention_2=True
#     )

# model.to(device)

# %%
# !pip install --upgrade optimum

# %%
# pipe = pipeline(
#     "automatic-speech-recognition",
#     model=model,
#     tokenizer=processor.tokenizer,
#     feature_extractor=processor.feature_extractor,
#     max_new_tokens=128,
#     chunk_length_s=15,
#     batch_size=16,
#     return_timestamps=True,
#     torch_dtype=torch_dtype,
#     device=device,
# )

# %% [markdown]
# #Distill Whisper

# %%
# !pip install -q transformers accelerate datasets[audio]
# #!pip install -q flash-attn --no-build-isolation
# !pip install --q optimum

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
# from optimum.bettertransformer import BetterTransformer

# %%
model_id = "distil-whisper/distil-medium.en"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True#, use_flash_attention_2=True
)
model.to(device)

# %%
processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=15,
    batch_size=16,
    torch_dtype=torch_dtype,
    device=device,
)

# %%
# %%timeit
result = pipe(audio)

# %%
result = pipe(audio)

# %%
result
